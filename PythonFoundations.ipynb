# %% [markdown]
# <a href="https://colab.research.google.com/github/tigrisoracleeval-coder/aiml-projects/blob/main/PythonFoundations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# # Python Foundations

# %%
print("Hello world!!")
# Out:
# Hello world!!

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %% [markdown]
# # Data Manipulation
